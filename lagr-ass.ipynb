# %%
from numpy.polynomial import Polynomial
from utils import solve_lagrange
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 1.05, 1.1, 1.15])
y = np.log10(np.tan(x))

poly = solve_lagrange(x,y)
str(poly)

space = np.linspace(0.5, 1.5)

plt.scatter(x,y)
plt.plot(space, poly(space))
# Out:
# L0 =   (-1.32825 + 3.6275 x - 3.3 x**2 + 1.0 x**3) / (-0.00075)
# L1 =   (-1.265 + 3.515 x - 3.25 x**2 + 1.0 x**3) / (0.00025)
# L2 =   (-1.2075 + 3.4075 x - 3.2 x**2 + 1.0 x**3) / (-0.00025)
# L3 =   (-1.155 + 3.305 x - 3.15 x**2 + 1.0 x**3) / (0.00075)
